# %% [markdown]
# # Practical_7: Matplotlib

# %% [markdown]
# ---
#
# ### Exercise 1:
# Create a simple line plot for `y = x` for `x` values ranging from 0 to 10.
#
# ```python
# # Exercise 1
# ```

# %%
import matplotlib.pylab as plt
import numpy as np

x = np.arange(11)
y = x
plt.plot(x, y)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 2:
# Plot `y = x^2` using Matplotlib for `x` values between -10 and 10.
#
# ```python
# # Exercise 2
# ```

# %%
x = np.arange(-10,11)
y = x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 3:
# Create a scatter plot with 50 random points where x and y values are between 0 and 10.
#
# ```python
# # Exercise 3
# ```

# %%
x = np.random.randint(0, 10, 50)
y = np.random.randint(0, 10, 50)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 4:
# Plot a sine wave using Matplotlib for `x` values between 0 and 2π.
#
# ```python
# # Exercise 4
# ```

# %%
x = np.linspace(0, 2*np.pi, 200)
plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 5:
# Create a bar chart for the following data: `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.
#
# ```python
# # Exercise 5
# ```

# %%
categories = ["A", "B", "C", "D"]
values = [3, 7, 5, 9]
plt.bar(categories, values)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 6:
# Create a histogram of 1000 random numbers generated from a normal distribution.
#
# ```python
# # Exercise 6
# ```

# %%
x = np.random.normal(0, 1, 1000)
plt.hist(x)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 7:
# Plot two line plots on the same graph: `y1 = x^2` and `y2 = x^3` for `x` ranging from 0 to 10.
#
# ```python
# # Exercise 7
# ```

# %%
x = np.arange(0,11)
plt.plot(x, x**2, c="r", label=r"$x^2$")
plt.plot(x, x**3, c="b", label=r"$x^3$")
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 8:
# Add titles, axis labels, and a legend to the plot in Exercise 7.
#
# ```python
# # Exercise 8
# ```

# %%
x = np.arange(0,11)
plt.plot(x, x**2, c="r", label=r"$x^2$")
plt.plot(x, x**3, c="b", label=r"$x^3$")
plt.title("plot $x^2$ and $x^3$")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 9:
# Create a subplot with 2 rows and 1 column. Plot `y1 = x^2` in the first subplot and `y2 = x^3` in the second.
#
# ```python
# # Exercise 9
# ```

# %%
fig, axes = plt.subplots(2,1)
axes[0].plot(x, x**2, c="b")
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")
axes[0].set_title("$x^2$")
axes[1].plot(x,x**3, c="g")
axes[1].set_xlabel("x")
axes[1].set_ylabel("y")
axes[1].set_title("$x^3$")

fig.tight_layout()

# %% [markdown]
# ---
#
# ### Exercise 10:
# Use a different color and linestyle for each line in a plot of three functions: `y1 = x`, `y2 = x^2`, and `y3 = x^3`.
#
# ```python
# # Exercise 10
# ```

# %%
x = np.linspace(-10,10,100)
plt.plot(x, x, c="r", ls="-", label=r"$y=x$")
plt.plot(x, x**2, c="b", ls="dashed", label=r"$y=x^2$")
plt.plot(x, x**3, c="g", ls="dotted", label=r"$y=x^3$")
plt.xlabel("x")
plt.ylabel("y")
plt.title("title of our figure")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 11:
# Create a pie chart with 5 segments labeled A, B, C, D, and E, with values `[25, 35, 20, 15, 5]`.
#
# ```python
# # Exercise 11
# ```

# %%
categories = ["A", "B", "C", "D", "E"]
values = [25,35,20,15,5]
plt.pie(values, labels=categories)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 12:
# Create a horizontal bar chart with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.
#
# ```python
# # Exercise 12
# ```

# %%
categories = ["A", "B", "C", "D"]
values = [3, 7, 5, 9]
plt.barh(values, categories)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 13:
# Change the figure size of a line plot to 10x6 inches.
#
# ```python
# # Exercise 13
# ```

# %%
plt.figure(figsize=(20, 7))
x = np.linspace(-10,10, 100)
plt.plot(x,x**2)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 14:
# Plot a filled area under the curve of `y = x^2` for `x` ranging from 0 to 10.
#
# ```python
# # Exercise 14
# ```

# %%
x = np.arange(0,11)
plt.fill_between(x, x**2)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 15:
# Change the style of the plot to `ggplot` and replot the sine wave from Exercise 4.
#
# ```python
# # Exercise 15
# ```

# %%
plt.style.use('ggplot')
x = np.linspace(-10,10,100)
plt.plot(x, np.sin(x), label=r"$y=\sin{x}$")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 16:
# Create a stacked bar chart for the following data: `Group A = [3, 5, 7]`, `Group B = [2, 6, 4]`, and `categories = ['X', 'Y', 'Z']`.
#
# ```python
# # Exercise 16
# ```

# %%
group_a = [3, 5, 7]
group_b = [2, 6, 4]
categories = ["x", "y", "z"]
plt.bar(categories, group_a, color="b")
plt.bar(categories, group_b, color="g", bottom=group_a)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 17:
# Create a plot with multiple subplots in a 2x2 grid. Plot `y1 = x`, `y2 = x^2`, `y3 = x^3`, and `y4 = x^4`.
#
# ```python
# # Exercise 17
# ```

# %%
x = np.linspace(-10,10,150)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.suptitle('y=x')
ax1.plot(x, x, label=r"y=x")
ax2.plot(x, x**2, label=r'$y=x^2')
ax3.plot(x, x**3, label=r'$y=x^3')
ax4.plot(x, x**4, label=r'$y=x^4')
for ax in fig.get_axes():
    ax.label_outer()

# %% [markdown]
# ---
#
# ### Exercise 18:
# Create a heatmap using a 2D array of random values with shape (5, 5).
#
# ```python
# # Exercise 18
# ```

# %%
data = np.random.rand(5,5)
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 19:
# Add error bars to a bar plot with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`, assuming the error is 1 for each value.
#
# ```python
# # Exercise 19
# ```

# %%
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
plt.bar(categories, values, color="g")
plt.errorbar(categories, values, [1, 1, 1, 1], color="b")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 20:
# Plot a sine wave using a dashed line and a cosine wave using a solid line on the same plot.
#
# ```python
# # Exercise 20
# ```

# %%
x = np.linspace(-10,10,200)

plt.plot(x, np.sin(x), ls="dashed", label=r"$y=\cos{x}$")
plt.plot(x, np.cos(x), ls="solid", label=r"$y=\sin{x}$")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 21:
# Plot a contour plot for the function `z = sin(x) + cos(y)` over a grid of `x` and `y` values ranging from -5 to 5.
#
# ```python
# # Exercise 21
# ```

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)
X,Y = np.meshgrid(x, y)
f = lambda a, b : np.cos(a)+np.sin(b)
plt.contour(X, Y, f(X,Y))
C = plt.contour(X, Y, f(X,Y), 8, colors='black')
plt.clabel(C, inline=1, fontsize=10)

plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 22:
# Create a box plot for a dataset generated with 100 random numbers from a normal distribution.
#
# ```python
# # Exercise 22
# ```

# %%
data = np.random.normal(1,1, 100)
plt.boxplot(data)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 23:
# Create a scatter plot with a color map applied to the points, where the color represents the value of the points.
#
# ```python
# # Exercise 23
# ```

# %%
x = np.random.randint(10, 50, 100)
y = np.random.randint(1, 50, 100)
plt.scatter(x, y, c=x)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 24:
# Use Matplotlib to display an image from a file.
#
# ```python
# # Exercise 24
# ```

# %%
import imageio
img = imageio.imread('./img.jpg')
image = np.asarray(img)
plt.imshow(image)
plt.grid(False)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 25:
# Create a plot with logarithmic scaling on both axes.
#
# ```python
# # Exercise 25
# ```

# %%
x = np.linspace(-10,10,200)
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 7))
ax1.plot(x, np.sin(x), ls="dashed", label=r"$y=\cos{x}$")
ax1.plot(x, np.cos(x), ls="solid", label=r"$y=\sin{x}$")

ax2.plot(x, np.sin(x), ls="dashed", label=r"$y=\cos{x}$")
ax2.plot(x, np.cos(x), ls="solid", label=r"$y=\sin{x}$")
ax2.set_yscale("log")
ax2.set_xscale("log")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 26:
# Create a 3D plot of the function `z = x^2 + y^2` over a grid of `x` and `y` values.
#
# ```python
# # Exercise 26
# ```

# %%
fig = plt.figure(figsize=(25, 10))

# inputs
x = np.arange(-4, 4, 0.25)
x = np.arange(-4, 4, 0.25)

X, Y = np.meshgrid(x,y)
ax = fig.add_subplot(1, 1, 1, projection='3d')
f = lambda x,y : x**2 + y**2
p = ax.plot_surface(X, Y, f(X,Y), rstride=4, cstride=4, linewidth=0)

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 27:
# Create a radar chart with 5 variables and random values between 0 and 1.
#
# ```python
# # Exercise 27
# ```

# %%
categories = ['Food Quality', 'Food Variety', 'Service Quality', 'Ambiance', 'Affordability']
categories = [*categories, categories[0]]

restaurant_1 = np.random.rand(5)
restaurant_2 = np.random.rand(5)
restaurant_3 = np.random.rand(5)
restaurant_4 = np.random.rand(5)
restaurant_5 = np.random.rand(5)
restaurant_1 = [*restaurant_1, restaurant_1[0]]
restaurant_2 = [*restaurant_2, restaurant_2[0]]
restaurant_3 = [*restaurant_3, restaurant_3[0]]
restaurant_4 = [*restaurant_4, restaurant_4[0]]
restaurant_4 = [*restaurant_4, restaurant_3[0]]

label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(restaurant_1))

plt.figure(figsize=(8, 8))
plt.subplot(polar=True)
plt.plot(label_loc, restaurant_1, label='Restaurant 1')
plt.plot(label_loc, restaurant_2, label='Restaurant 2')
plt.plot(label_loc, restaurant_3, label='Restaurant 3')
plt.title('Restaurant comparison', size=20, y=1.05)
lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories)
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 28:
# Create a violin plot to show the distribution of a dataset generated with 1000 random numbers from a normal distribution.
#
# ```python
# # Exercise 28
# ```

# %%
data = np.random.normal(1,1,1000)
plt.violinplot(data)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 29:
# Create a bar chart with different colors for each bar.
#
# ```python
# # Exercise 29
# ```

# %%
data = np.random.randint(1,50, 5)
height = [10, 20, 30, 40, 50]
plt.bar(data, height, color=['red', 'yellow', 'black', 'blue', 'orange'])
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 30:
# Create a stem plot for the function `y = sin(x)` for `x` values between 0 and 2π.
#
# ```python
# # Exercise 30
# ```

# %%
x = np.linspace(0, 2*np.pi, 10000)
plt.stem(x, np.sin(x))
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 31:
# Create a scatter plot with markers of different sizes.
#
# ```python
# # Exercise 31
# ```

# %%
x = np.random.randint(10, 100, 100)
y = np.random.randint(10, 100, 100)
sizes = np.random.rand(100) * 500
plt.scatter(x, y, s=sizes, alpha=0.5)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 32:
# Plot a cumulative histogram of 1000 random numbers generated from a uniform distribution.
#
# ```python
# # Exercise 32
# ```

# %%
data = np.random.uniform(10, 100, 1000)
plt.hist( data, 25, density=True,cumulative=True, label="Cumulative histogram")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 33:
# Create a pie chart with custom colors for each segment.
#
# ```python
# # Exercise 33
# ```

# %%
categories = ["A", "B", "C", "D", "E"]
values = [25,35,20,15,5]
plt.pie(values, labels=categories, colors=['red', 'yellow', 'black', 'blue', 'orange'])
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 34:
# Create a plot with twin y-axes where one axis represents `y = x` and the other represents `y = x^2`.
#
# ```python
# # Exercise 34
# ```

# %%
x = np.linspace(-10,10, 100)

plt.plot(x, x, color="b")
ax1 = plt.twinx()
ax1.plot(x, x**2, color="g")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 35:
# Plot a density plot of 1000 random values from a normal distribution.
#
# ```python
# # Exercise 35
# ```

# %%
from scipy.stats import gaussian_kde
data = np.random.normal(1,1,1000)

plt.hist(data, density=True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 36:
# Create a histogram and add a kernel density estimate (KDE) to the plot.
#
# ```python
# # Exercise 36
# ```

# %% [markdown]
# ---
#
# ### Exercise 37:
# Add gridlines to a line plot and change the color and linestyle of the grid.
#
# ```python
# # Exercise 37
# ```
#
# ---
#
# ### Exercise 38:
# Create a bar chart with annotations showing the height of each bar above the bar.
#
# ```python
# # Exercise 38
# ```
#
# ---
#
# ### Exercise 39:
# Create a filled contour plot for the function `z = x^2 + y^2` over a grid of `x` and `y` values.
#
# ```python
# # Exercise 39
# ```
#
# ---
#
# ### Exercise 40:
# Create a stacked area plot using three random datasets.
#
# ```python
# # Exercise 40
# ```
#
# ---
#
# ### Exercise 41:
# Create a bar chart with error bars, where the error values are proportional to the bar values.
#
# ```python
# # Exercise 41
# ```
#
# ---
#
# ### Exercise 42:
# Create a wind rose chart using random wind direction and speed data.
#
# ```python
# # Exercise 42
# ```
#
# ---
#
# ### Exercise 43:
# Plot a cumulative frequency curve for a dataset of 100 random numbers.
#
# ```python
# # Exercise 43
# ```
#
# ---
#
# ### Exercise 44:
# Create a waterfall chart using Matplotlib to show the changes in a sequence of values.
#
# ```python
# # Exercise 44
# ```
#
# ---
#
# ### Exercise 45:
# Use the `imshow` function to display a 10x10 matrix of random values as an image.
#
# ```python
# # Exercise 45
# ```
#
# ---
#
# ### Exercise 46:
# Create a line plot with different markers for each point.
#
# ```python
# # Exercise 46
# ```
#
# ---
#
# ### Exercise 47:
# Create a time series plot using Matplotlib and plot random data over a range of dates.
#
# ```python
# # Exercise 47
# ```
#
# ---
#
# ### Exercise 48:
# Create a bar chart with bars colored by category.
#
# ```python
# # Exercise 48
# ```
#
# ---
#
# ### Exercise 49:
# Create a radar chart to visualize the strengths of five different attributes.
#
# ```python
# # Exercise 49
# ```
#
# ---
#
# ### Exercise 50:
# Create a 3D scatter plot with random values for x, y, and z.
#
# ```python
# # Exercise 50
# ```
#
# ---
